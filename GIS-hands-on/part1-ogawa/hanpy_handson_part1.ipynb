# %%
# Important library for many geopython libraries
# !apt install gdal-bin python-gdal python3-gdal &> /dev/null
# Install rtree - Geopandas requirment
# !apt install python3-rtree &> /dev/null
# Install Geopandas
# !pip install geopandas &> /dev/null
# Install descartes - Geopandas requirment
# !pip install descartes &> /dev/null
# !pip install plotly -U &> /dev/null
# !pip install rasterio &> /dev/null
# !pip install rioxarray &> /dev/null

# %%
import geopandas as gpd
import pandas as pd
import folium
import shapely
import xarray as xr
import rioxarray as rxr

# %%
## geojsonファイルで

data = gpd.read_file('/content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/my_activity.geojson')
data
# Out:
#       地名                    geometry
# 0    銀閣寺  POINT (135.79821 35.02702)
# 1    金閣寺  POINT (135.72924 35.03937)
# 2  MKボウル  POINT (135.74609 35.06682)
# 3    京都駅  POINT (135.75877 34.98585)

# %% [markdown]
# ## 可視化

# %%
center = shapely.geometry.Polygon(data['geometry']).centroid
m = folium.Map([center.y, center.x])

folium.GeoJson(data).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ac2f50b05f09097ec6ab3454161cba5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ac2f50b05f09097ec6ab3454161cba5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6ac2f50b05f09097ec6ab3454161cba5 = L.map(
#                 &quot;map_6ac2f50b05f09097ec6ab3454161cba5&quot;,
#                 {
#                     center: [35.003343033102766, 135.7804960365497],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8683e99294d0eef07188edfe7e80d066 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6ac2f50b05f09097ec6ab3454161cba5);
#
#
#
#         function geo_json_7e917b3be46ba8db9a0b71f444f9c109_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7e917b3be46ba8db9a0b71f444f9c109 = L.geoJson(null, {
#                 onEachFeature: geo_json_7e917b3be46ba8db9a0b71f444f9c109_onEachFeature,
#
#         });
#
#         function geo_json_7e917b3be46ba8db9a0b71f444f9c109_add (data) {
#             geo_json_7e917b3be46ba8db9a0b71f444f9c109
#                 .addData(data)
#                 .addTo(map_6ac2f50b05f09097ec6ab3454161cba5);
#         }
#             geo_json_7e917b3be46ba8db9a0b71f444f9c109_add({&quot;bbox&quot;: [135.7292431, 34.985849, 135.7982058, 35.0668248], &quot;features&quot;: [{&quot;bbox&quot;: [135.7982058, 35.0270213, 135.7982058, 35.0270213], &quot;geometry&quot;: {&quot;coordinates&quot;: [135.7982058, 35.0270213], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;\u5730\u540d&quot;: &quot;\u9280\u95a3\u5bfa&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [135.7292431, 35.03937, 135.7292431, 35.03937], &quot;geometry&quot;: {&quot;coordinates&quot;: [135.7292431, 35.03937], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;\u5730\u540d&quot;: &quot;\u91d1\u95a3\u5bfa&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [135.746086, 35.0668248, 135.746086, 35.0668248], &quot;geometry&quot;: {&quot;coordinates&quot;: [135.746086, 35.0668248], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;\u5730\u540d&quot;: &quot;MK\u30dc\u30a6\u30eb&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [135.7587667, 34.985849, 135.7587667, 34.985849], &quot;geometry&quot;: {&quot;coordinates&quot;: [135.7587667, 34.985849], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;\u5730\u540d&quot;: &quot;\u4eac\u90fd\u99c5&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## shapely.geometry.*の型
#
# - 点: Point
# - 線: Linestring
# - 面: Polygon
#
# - それぞれにMulti*がある

# %%
# 点
data.loc[0, 'geometry']

# %%
# 点
data.plot()

# %%
# 線

two1 = shapely.geometry.LineString([data.loc[0, 'geometry'], data.loc[2, 'geometry']])
two1

# %%
# 面

polygon = shapely.geometry.Polygon([
    data.loc[0, 'geometry'],
    data.loc[2, 'geometry'],
    data.loc[1, 'geometry'],
    data.loc[3, 'geometry']
])
polygon

# %% [markdown]
# ## 面積を調べたい場合

# %%
# 座標参照系を調べる
data.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# メートル表現に変更する
data = data.to_crs('EPSG:6674')
data
# Out:
#       地名                        geometry
# 0    銀閣寺  POINT (-18413.537 -107922.597)
# 1    金閣寺  POINT (-24702.618 -106537.855)
# 2  MKボウル  POINT (-23158.194 -103496.311)
# 3    京都駅  POINT (-22023.357 -112481.852)

# %%
# 面積　キロ平方メートル

men = shapely.geometry.Polygon([
    data.loc[0, 'geometry'],
    data.loc[2, 'geometry'],
    data.loc[1, 'geometry'],
    data.loc[3, 'geometry']
])
men.area / 1000000
# Out:
# 27.46967181332873

# %%
# !unzip /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/ame_master.zip -d /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data
# Out:
# Archive:  /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/ame_master.zip
#   inflating: /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/ame_master_20220701.csv

# %%
# 度・分・秒でやらかし事例

df = pd.read_csv('/content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/ame_master_20220701.csv', encoding='cp932')
df['ido'] = df['緯度(度)'] + df['緯度(分)']/100
df['keido'] = df['経度(度)'] + df['経度(分)']/100

# %%
df.head()
# Out:
#   都府県振興局  観測所番号 種類  観測所名     ｶﾀｶﾅ名                    所在地  緯度(度)  緯度(分)  \
# 0     宗谷  11001  四   宗谷岬    ｿｳﾔﾐｻｷ                 稚内市宗谷岬     45   31.2
# 1     宗谷  11016  官    稚内     ﾜｯｶﾅｲ          稚内市開運　稚内地方気象台     45   24.9
# 2     宗谷  11046  四    礼文      ﾚﾌﾞﾝ        礼文郡礼文町大字香深村トンナイ     45   18.3
# 3     宗谷  11061  官    声問      ｺｴﾄｲ  稚内市大字声問村字声問　稚内航空気象観測所     45   24.2
# 4     宗谷  11076  四  浜鬼志別  ﾊﾏｵﾆｼﾍﾞﾂ             宗谷郡猿払村浜鬼志別     45   20.1
#
#    経度(度)  経度(分)  海面上の高さ(ｍ) 風速計の高さ(ｍ) 温度計の高さ(ｍ)    観測開始年月日    備考1          備考2  \
# 0    141   56.1         26      10.1       1.5  昭53.10.30      －            －
# 1    141   40.7          3      24.1         －   #昭50.4.1  11903            －
# 2    141    2.7         65       9.9       1.5  平15.10.17      －            －
# 3    141   48.1          8        10         －    平15.1.1  11904  日照・湿度・気圧を除く
# 4    142   10.2         13       6.5       1.5  昭53.10.30  11900        湿度を除く
#
#       ido    keido
# 0  45.312  141.561
# 1  45.249  141.407
# 2  45.183  141.027
# 3  45.242  141.481
# 4  45.201  142.102

# %%
center_ido = df['ido'].mean()
center_keido = df['keido'].mean()

m = folium.Map([center_ido, center_keido])

for i in df.index:
    folium.Marker([df.loc[i, 'ido'], df.loc[i, 'keido']], popup=df.loc[i, '観測所名']).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a669f72bd74b8273b43d8f0709fb01f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a669f72bd74b8273b43d8f0709fb01f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a669f72bd74b8273b43d8f0709fb01f9 = L.map(
#                 &quot;map_a669f72bd74b8273b43d8f0709fb01f9&quot;,
#                 {
#                     center: [36.44962937595129, 136.94654033485543],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_deec0edc9b3b8d9150e34f40d7f97e42 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a669f72bd74b8273b43d8f0709fb01f9);
#
#
#             var marker_a54b39127d338238ed61572ae749a651 = L.marker(
#                 [45.312, 141.561],
#                 {}
#             ).addTo(map_a669f72bd74b8273b43d8f0709fb01f9);
#
#
#         var popup_8897abb5f792ddf67531efee701e9a39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2af969ec2dfe2ee80fdbc15e62b921e6 = $(`&lt;div id=&quot;html_2af969ec2dfe2ee80fdbc15e62b921e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;宗谷岬&lt;/div&gt;`)[0];
#             popup_8897abb5f792ddf67531efee701e9a39.setContent(html_2af969ec2dfe2ee80fdbc15e62b921e6);
#
#
#         marker_a54b39127d338238ed61572ae749a651.bindPopup(popup_8897abb5f792ddf67531efee701e9a39)
#         ;
#
#
#
#
#             var marker_735e8fe7111c8ff71a9882b3995332fb = L.marker(
#                 [45.249, 141.407],
#                 {}
#             ).addTo(map_a669f72bd74b8273b43d8f0709fb01f9);
#
#
#         var popup_2991b5692801a01ce96d037240c1b719 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cfb27df9705d3d98e5f2e7ba4eb5d583 = $(`&lt;div id=&quot;html_cfb27df9705d3d98e5f2e7ba4eb5d583&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;稚内&lt;/div&gt;`)[0];
#             popup_2991b5692801a01ce96d037240c1b719.setContent(html_cfb27df9705d3d98e5f2e7ba4eb5d583);
#
#
#         marker_735e8fe7111c8ff71a9882b3995332fb.bindPopup(popup_2991b5692801a01ce96d037240c1b719)
#         ;
#
#
#
#
#             var marker_6f551027c9c106ef11d805298bfccbba = L.marker(
#                 [45.183, 141.027],
#                 {}
#             ).addTo(map_a669f72bd74b8273b43d8f0709fb01f9);
#
#
#         var popup_2983eb8b013d720e2cfad7129e5023c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2a93ff93121c4ad1e1be8851972d5c33 = $(`&lt;div id=&quot;html_2a93ff93121c4ad1e1be8851972d5c33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;礼文&lt;/div&gt;`)[0];
#             popup_2983eb8b013d720e2cfad7129e5023c1.setContent(html_2a93ff93121c4ad1e1be8851972d5c33);
#
#
#         marker_6f551027c9c106ef11d805298bfccbba.bindPopup(popup_2983eb8b013d720e2cfad7129e5023c1)
#         ;
#
#
#
#
#             var marker_f1c11cb7ef2061d0936d64c3cf86b4de = L.marker(
#                 [45.242, 141.481],
#                 {}
#             ).addTo(map_a669f72bd74b8273b43d8f0709fb01f9);
#
#
#         var popup_7ea7bf7205249149f4c19b6118aa236d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_688142b8c8dc35c6655b79bd28ed9f3a = $(`&lt;div id=&quot;html_688142b8c8dc35c6655b79bd28ed9f3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;声問&lt;/div&gt;`)[0];
#             popup_7ea7bf7205249149f4c19b6118aa236d.setContent(html_688142b8c8dc35c6655b79bd28ed9f3a);
#
#
#         marker_f1c11cb7ef2061d0936d64c3cf86b4de.bindPopup(popup_7ea7bf7205249149f4c19b6118aa236d)
#         ;
#
#
#
#
#             var marker_f2596ffb730e873ee069a9fdf27bebf3 = L.marker(
#                 [45.201, 142.102],
#                 {}
#             ).addTo(map_a669f72bd74b8273b43d8f0709fb01f9);
#
#
#         var popup_48a07e8f6838ae679262235dce71642e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8df60b50651a3894b7cfc854b21af617 = $(`&lt;div id=&quot;html_8df60b50651a3894b7cfc854b21af617&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;浜鬼志別&lt;/div&gt;`)[0];
#             popup_48a07e8f6838ae679262235dce71642e.setContent(html_8df60b50651a3894b7cfc854b21af617);
#
#
#         marker_f2596ffb730e873ee069a9fdf27bebf3.bindPopup(popup_48a07e8f6838ae679262235dce71642e)
#         ;
#
#
#
#
#             var marker_aa347f50f5fa0d71cb7414010673e1a6 = L.marker(
#                 [45.145, 141.112],
#                 {}
#             ).addTo(map_a669f72bd74b8273b43d8f0709fb01f9);
#
#
#         var popup_b63ab5069456ebc525156e3d5b4fc6c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c2f5880fcde0bb13ca806fca69c053de = $(`&lt;div id=&quot;html_c2f5880fcde0bb13ca806fca69c053de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;本泊&lt;/div&

# %%
df['fixed_ido'] =  df['緯度(度)'] + df['緯度(分)']/60
df['fixed_keido'] = df['経度(度)'] + df['経度(分)']/60

# %%
center_ido = df['fixed_ido'].mean()
center_keido = df['fixed_keido'].mean()

m = folium.Map([center_ido, center_keido])

for i in df.index:
    folium.Marker([df.loc[i, 'fixed_ido'], df.loc[i, 'fixed_keido']], popup=df.loc[i, '観測所名']).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d690ab5c151d5d49e17f75a4375ae20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d690ab5c151d5d49e17f75a4375ae20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0d690ab5c151d5d49e17f75a4375ae20 = L.map(
#                 &quot;map_0d690ab5c151d5d49e17f75a4375ae20&quot;,
#                 {
#                     center: [36.64994038559107, 137.1488508371385],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d66a2659859498191ab6812da8420d1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0d690ab5c151d5d49e17f75a4375ae20);
#
#
#             var marker_5f243739e3bbdda23f18df68255b2eb0 = L.marker(
#                 [45.52, 141.935],
#                 {}
#             ).addTo(map_0d690ab5c151d5d49e17f75a4375ae20);
#
#
#         var popup_ca78dfaacdcdaf86aee00705e6cf6f72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_60d1a5b3d27ae9b5c7c397e77a06f94f = $(`&lt;div id=&quot;html_60d1a5b3d27ae9b5c7c397e77a06f94f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;宗谷岬&lt;/div&gt;`)[0];
#             popup_ca78dfaacdcdaf86aee00705e6cf6f72.setContent(html_60d1a5b3d27ae9b5c7c397e77a06f94f);
#
#
#         marker_5f243739e3bbdda23f18df68255b2eb0.bindPopup(popup_ca78dfaacdcdaf86aee00705e6cf6f72)
#         ;
#
#
#
#
#             var marker_4748e6d7e2178da877e2c2eef2dcbaa4 = L.marker(
#                 [45.415, 141.67833333333334],
#                 {}
#             ).addTo(map_0d690ab5c151d5d49e17f75a4375ae20);
#
#
#         var popup_346cafd52e654f7b35b76468393660fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_664319c1baa73d51ab29fd91472b0f6f = $(`&lt;div id=&quot;html_664319c1baa73d51ab29fd91472b0f6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;稚内&lt;/div&gt;`)[0];
#             popup_346cafd52e654f7b35b76468393660fe.setContent(html_664319c1baa73d51ab29fd91472b0f6f);
#
#
#         marker_4748e6d7e2178da877e2c2eef2dcbaa4.bindPopup(popup_346cafd52e654f7b35b76468393660fe)
#         ;
#
#
#
#
#             var marker_c3375bb5e1d510efef237ec3d4aef536 = L.marker(
#                 [45.305, 141.045],
#                 {}
#             ).addTo(map_0d690ab5c151d5d49e17f75a4375ae20);
#
#
#         var popup_fe41fee2f29d6877fd318273ede6aaff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_777c7952c9c647ea237ff7d97d31427d = $(`&lt;div id=&quot;html_777c7952c9c647ea237ff7d97d31427d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;礼文&lt;/div&gt;`)[0];
#             popup_fe41fee2f29d6877fd318273ede6aaff.setContent(html_777c7952c9c647ea237ff7d97d31427d);
#
#
#         marker_c3375bb5e1d510efef237ec3d4aef536.bindPopup(popup_fe41fee2f29d6877fd318273ede6aaff)
#         ;
#
#
#
#
#             var marker_d60863b3a3988a8735eeb17c1b82cb56 = L.marker(
#                 [45.403333333333336, 141.80166666666668],
#                 {}
#             ).addTo(map_0d690ab5c151d5d49e17f75a4375ae20);
#
#
#         var popup_1326c61ca4c3cb25eba2d2106d774bbe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_475fa209573f1c5b8afcbf333d96e251 = $(`&lt;div id=&quot;html_475fa209573f1c5b8afcbf333d96e251&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;声問&lt;/div&gt;`)[0];
#             popup_1326c61ca4c3cb25eba2d2106d774bbe.setContent(html_475fa209573f1c5b8afcbf333d96e251);
#
#
#         marker_d60863b3a3988a8735eeb17c1b82cb56.bindPopup(popup_1326c61ca4c3cb25eba2d2106d774bbe)
#         ;
#
#
#
#
#             var marker_cb155021e2bf780aa12234af7a0b4eed = L.marker(
#                 [45.335, 142.17],
#                 {}
#             ).addTo(map_0d690ab5c151d5d49e17f75a4375ae20);
#
#
#         var popup_f012e6fe342e71464fae3a504aa03bc2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8c7dd5c81899a54bf65510aadba37815 = $(`&lt;div id=&quot;html_8c7dd5c81899a54bf65510aadba37815&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;浜鬼志別&lt;/div&gt;`)[0];
#             popup_f012e6fe342e71464fae3a504aa03bc2.setContent(html_8c7dd5c81899a54bf65510aadba37815);
#
#
#         marker_cb155021e2bf780aa12234af7a0b4eed.bindPopup(popup_f012e6fe342e71464fae3a504aa03bc2)
#         ;
#
#
#
#
#             var marker_951f31a016cd74f5f875df8386948c74 = L.marker(
#                 [45.24166666666667, 141.18666666666667],
#                 {}
#             ).addTo(map_0d690ab5c151d5d49e17f75a4375ae20);
#
#
#         var popup_38b0dc1c0785ad7abfe29fdfcb2c2da7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fe3eafba7a1a244f46087da3431d1baa = $(`&lt;div id=&quot;html_fe3eafba7a1a244f46087da3431d1baa&quot; style=&quo

# %% [markdown]
# ## 土地利用細分メッシュ（ラスタ）
#
# - https://nlftp.mlit.go.jp/ksj/gml/datalist/KsjTmplt-L03-b_r.html
# - 国土数値情報ダウンロード

# %%
da = rxr.open_rasterio('/content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/L03-b-14_5235.tif')
da
# Out:
# <xarray.DataArray (band: 1, y: 800, x: 800)>
# [640000 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 135.0 135.0 135.0 135.0 ... 136.0 136.0 136.0 136.0
#   * y            (y) float64 35.33 35.33 35.33 35.33 ... 34.67 34.67 34.67 34.67
#     spatial_ref  int64 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0

# %%
da.plot()

# %%
my_activity_bounds = polygon.bounds
my_area = da.sel(x=slice(my_activity_bounds[0], my_activity_bounds[2]), 
                 y=slice(my_activity_bounds[3], my_activity_bounds[1]))
my_area
# Out:
# <xarray.DataArray (band: 1, y: 97, x: 56)>
# array([[[50, 50, ..., 50, 50],
#         [50, 50, ..., 50, 50],
#         ...,
#         [70, 70, ..., 70, 70],
#         [70, 70, ..., 70, 70]]], dtype=uint8)
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 135.7 135.7 135.7 135.7 ... 135.8 135.8 135.8 135.8
#   * y            (y) float64 35.07 35.07 35.06 35.06 ... 34.99 34.99 34.99 34.99
#     spatial_ref  int64 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0

# %%
my_area.plot()

# %% [markdown]
# ## 行政区域情報（ベクター）
#
# - https://nlftp.mlit.go.jp/ksj/gml/datalist/KsjTmplt-N03-v3_0.html#
# - 国土数値情報ダウンロード

# %%
# !unzip /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/N03-20210101_26_GML-20220910T024702Z-001.zip -d /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data
# Out:
# Archive:  /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/N03-20210101_26_GML-20220910T024702Z-001.zip
#   inflating: /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/N03-20210101_26_GML/N03-21_26_210101.dbf
#   inflating: /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/N03-20210101_26_GML/N03-21_26_210101.shx
#   inflating: /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/N03-20210101_26_GML/N03-21_26_210101.prj
#   inflating: /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/N03-20210101_26_GML/KS-META-N03-21_26_210101.xml
#   inflating: /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/N03-20210101_26_GML/N03-21_26_210101.xml
#   inflating: /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/N03-20210101_26_GML/N03-21_26_210101.geojson
#   inflating: /content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/N03-20210101_26_GML/N03-21_26_210101.shp

# %%
data = gpd.read_file('/content/drive/MyDrive/work/2022/LT/202209-hanpy-handson/data/N03-20210101_26_GML/N03-21_26_210101.geojson')
data
# Out:
#     N03_001 N03_002 N03_003 N03_004 N03_007  \
# 0       京都府    None     京都市      北区   26101
# 1       京都府    None     京都市     上京区   26102
# 2       京都府    None     京都市     左京区   26103
# 3       京都府    None     京都市     中京区   26104
# 4       京都府    None     京都市     東山区   26105
# ..      ...     ...     ...     ...     ...
# 994     京都府    None     与謝郡     伊根町   26463
# 995     京都府    None     与謝郡     伊根町   26463
# 996     京都府    None     与謝郡     伊根町   26463
# 997     京都府    None     与謝郡     伊根町   26463
# 998     京都府    None     与謝郡    与謝野町   26465
#
#                                               geometry
# 0    POLYGON ((135.72539 35.17080, 135.72552 35.170...
# 1    POLYGON ((135.75062 35.03822, 135.75079 35.038...
# 2    POLYGON ((135.80481 35.31708, 135.80586 35.316...
# 3    POLYGON ((135.73195 35.02251, 135.73195 35.022...
# 4    POLYGON ((135.78466 35.01035, 135.78468 35.009...
# ..                                                 ...
# 994  POLYGON ((135.23382 35.76889, 135.23381 35.768...
# 995  POLYGON ((135.23337 35.76924, 135.23336 35.769...
# 996  POLYGON ((135.23317 35.76923, 135.23318 35.769...
# 997  POLYGON ((135.23318 35.76935, 135.23317 35.769...
# 998  POLYGON ((135.17732 35.60663, 135.17748 35.606...
#
# [999 rows x 6 columns]

# %%
data.loc[0, 'geometry']

# %%
data1 = data.to_crs('EPSG:4326')
data1['me'] = data1.geometry.map(lambda x: x.intersects(polygon))
my_data = data1[data1['me'] == True]
my_data
# Out:
#   N03_001 N03_002 N03_003 N03_004 N03_007  \
# 0     京都府    None     京都市      北区   26101
# 1     京都府    None     京都市     上京区   26102
# 2     京都府    None     京都市     左京区   26103
# 3     京都府    None     京都市     中京区   26104
# 4     京都府    None     京都市     東山区   26105
# 5     京都府    None     京都市     下京区   26106
#
#                                             geometry    me
# 0  POLYGON ((135.72539 35.17080, 135.72552 35.170...  True
# 1  POLYGON ((135.75062 35.03822, 135.75079 35.038...  True
# 2  POLYGON ((135.80481 35.31708, 135.80586 35.316...  True
# 3  POLYGON ((135.73195 35.02251, 135.73195 35.022...  True
# 4  POLYGON ((135.78466 35.01035, 135.78468 35.009...  True
# 5  POLYGON ((135.77017 35.00428, 135.77019 35.003...  True

# %%
center = shapely.geometry.MultiPolygon(my_data.geometry.values).centroid
map = folium.Map([center.y, center.x],
                 tiles='https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}',
                 attr='google map'
                 )
folium.GeoJson(my_data, tooltip=folium.features.GeoJsonTooltip(fields=['N03_003', 'N03_004'])).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f0851776d7efb7996f6a4070a98b827 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f0851776d7efb7996f6a4070a98b827&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6f0851776d7efb7996f6a4070a98b827 = L.map(
#                 &quot;map_6f0851776d7efb7996f6a4070a98b827&quot;,
#                 {
#                     center: [35.13706931358284, 135.772023347024],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83f4ebc07f3e10c56f1c0c813817ba5d = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;google map&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f0851776d7efb7996f6a4070a98b827);
#
#
#
#         function geo_json_5a3999bf3e7f2af6f9f86e3798f03c63_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5a3999bf3e7f2af6f9f86e3798f03c63 = L.geoJson(null, {
#                 onEachFeature: geo_json_5a3999bf3e7f2af6f9f86e3798f03c63_onEachFeature,
#
#         });
#
#         function geo_json_5a3999bf3e7f2af6f9f86e3798f03c63_add (data) {
#             geo_json_5a3999bf3e7f2af6f9f86e3798f03c63
#                 .addData(data)
#                 .addTo(map_6f0851776d7efb7996f6a4070a98b827);
#         }
#             geo_json_5a3999bf3e7f2af6f9f86e3798f03c63_add({&quot;bbox&quot;: [135.64696500543073, 34.969954720933686, 135.86075527853336, 35.32123889186141], &quot;features&quot;: [{&quot;bbox&quot;: [135.64696500543073, 35.02226333268669, 135.7725522175109, 35.171511386741145], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[135.7253874967356, 35.1708044413719], [135.72551917007365, 35.1708011084844], [135.7255647207353, 35.17081166742457], [135.725755278983, 35.170852504739344], [135.72590111484465, 35.17089027896327], [135.72600555041583, 35.17091333308389], [135.72608472043362, 35.17093555892893], [135.7261852790275, 35.17096110776896], [135.72625360591928, 35.17096444155578], [135.7263274969165, 35.17094666735488], [135.72648639363217, 35.17087472069187], [135.72658277577455, 35.17082805397155], [135.72671527828754, 35.17076333336121], [135.72678306108946, 35.17069333283109], [135.72680472036166, 35.17064361291244], [135.72680778165386, 35.17057166714875], [135.72681500590784, 35.170511107701486], [135.72681972734858, 35.170457505409615], [135.72684389033338, 35.17041250513307], [135.72688888431458, 35.17037361305188], [135.72692500558458, 35.170337505271675], [135.7269638904712, 35.17031055888526], [135.72715472031416, 35.1702222247759], [135.72731055753627, 35.170182224729956], [135.72745444906366, 35.170193612845026], [135.7275141622489, 35.170231946447245], [135.7276608299834, 35.17032583836681], [135.72790250299818, 35.170507225328265], [135.72809167269259, 35.170606108485174], [135.72825693840707, 35.170717225119915], [135.72844444885231, 35.17082000054262], [135.72850749672364, 35.17085917141367], [135.7285705580848, 35.170883053809916], [135.7286186115598, 35.17089222509617], [135.72868472072332, 35.17087110811519], [135.72882472088418, 35.170802505131576], [135.72905389062464, 35.17072417148336], [135.72918306025008, 35.17066999992062], [135.72933333246738, 35.1705830543645], [135.7293497280076, 35.170573053903354], [135.72951055736644, 35.17047499992134], [135.72960055791953, 35.17041805395007], [135.72966666708305, 35.17033694589338], [135.72971167275557, 35.17028889241851], [135.72978082972156, 35.17020805415842], [135.729825550309, 35.17016305388188], [135.7298794412833, 35.170123892004085], [135.73005861141587, 35.17005722526079], [135.7302419454095, 35.16998250508857], [135.7304280538117, 35.1699852794971], [135.73056917003123, 35.16998250508857], [135.73067444826722, 35.16994944151355], [135.73075555092805, 35.16991027873644], [135.73086639326948, 35.16987417095629], [135.73093917000676, 35.16963777516327], [135.73094472062246, 35.169480838070285], [135.73095027123804, 35.16936055914255], [135.73093917000676, 35.16912250499968], [135.73089138722776, 35.168962775511716], [135.7307961085536, 35.168789171283265], [135.73073693855895, 35.16863527929473], [135.73070527882567, 35.16850138732923], [135.73068749653078, 35.168363891780245], [135.73069472078475, 35.168261387053406], [135.7307263940079, 35.168180278996715], [135.73086416295087, 35.168007775538456], [135.73112221801603, 35.16772389194409], [135.73130500522188, 35.1675213871024], [135.73139693841802, 35.16737333351256], [135.7314322179226, 35.1672283331211], [135.731415005798, 35.1670347207758], [135.73139360553057, 35.166923053755966], [135.7313
